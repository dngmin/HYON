# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('simulate_result_data.csv')

# %matplotlib qt5
def dd():
    df.plot('x [m]','y [m]')
dd()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
df=pd.read_csv('simulate_result_data.csv')

fig=plt.figure()
ax=plt.axes(projection='3d')

x=df['x [m]']
y=df['x [m]']
z=df['y [m]']

ax.plot(x,y,z)

# %%
import pandas as pd


df=pd.read_csv('simulate_result_data.csv')
df
# Out:
#      t [s]       x [m]       y [m]         vx         vy
# 0      0.0    0.000000    0.000000   0.000000   0.000000
# 1      0.1    0.091188    0.419718   0.911877   4.197177
# 2      0.2    0.273563    1.259153   1.823753   8.394355
# 3      0.3    0.547163    2.518308   2.736001  12.591551
# 4      0.4    0.912063    4.197184   3.648999  16.788755
# ..     ...         ...         ...        ...        ...
# 124   12.4  246.960772  641.080123  22.014127   3.325926
# 125   12.5  249.162185  641.314716  22.014127   2.345926
# 126   12.6  251.363598  641.451308  22.014127   1.365926
# 127   12.7  253.565010  641.489901  22.014127   0.385926
# 128   12.8  255.766423  641.430493  22.014127  -0.594074
#
# [129 rows x 5 columns]
