# %% [markdown]
# # 6. 데이터 선택 (기본)

# %%
import pandas as pd
df= pd.read_excel('fruit.xlsx',index_col='no')
df
# Out:
#         日本語     English    한글  kcal
# no
# no1     リンゴ       apple    사과  54.0
# no2    オレンジ      orange   오랜지  47.1
# no3  パイナップル   pineapple  파인애플  50.9
# no4     イチゴ  strawberry    딸기  33.9
# no5      ナシ        pear     배  57.1

# %% [markdown]
# ## Column 선택 (label)

# %%
df['English']
# Out:
# no
# no1         apple
# no2        orange
# no3     pineapple
# no4    strawberry
# no5          pear
# Name: English, dtype: object

# %%
df[['English','日本語']]
# Out:
#         English     日本語
# no
# no1       apple     リンゴ
# no2      orange    オレンジ
# no3   pineapple  パイナップル
# no4  strawberry     イチゴ
# no5        pear      ナシ

# %% [markdown]
# ## Column 선택 (정수 index)

# %%
df.columns
# Out:
# Index(['日本語', 'English', '한글', 'kcal'], dtype='object')

# %%
df.columns[0]
# Out:
# '日本語'

# %%
df.columns[3]
# Out:
# 'kcal'

# %%
df[df.columns[0]]  # == df['日本語']
# Out:
# no
# no1       リンゴ
# no2      オレンジ
# no3    パイナップル
# no4       イチゴ
# no5        ナシ
# Name: 日本語, dtype: object

# %%
df[df.columns[-1]] # 맨 끝에 있는 값
# Out:
# no
# no1    54.0
# no2    47.1
# no3    50.9
# no4    33.9
# no5    57.1
# Name: kcal, dtype: float64

# %% [markdown]
# ## 슬라이싱

# %%
df
# Out:
#         日本語     English    한글  kcal
# no
# no1     リンゴ       apple    사과  54.0
# no2    オレンジ      orange   오랜지  47.1
# no3  パイナップル   pineapple  파인애플  50.9
# no4     イチゴ  strawberry    딸기  33.9
# no5      ナシ        pear     배  57.1

# %%
df['kcal'][0:2] # 0~1까지 의 kcal 데이터
# Out:
# no
# no1    54.0
# no2    47.1
# Name: kcal, dtype: float64

# %%
df[['日本語','한글']][:3] #처음 3개의 정보
# Out:
#         日本語    한글
# no
# no1     リンゴ    사과
# no2    オレンジ   오랜지
# no3  パイナップル  파인애플

# %%
df[3:] # 4~ 정보를 가져옴
# Out:
#      日本語     English  한글  kcal
# no
# no4  イチゴ  strawberry  딸기  33.9
# no5   ナシ        pear   배  57.1
