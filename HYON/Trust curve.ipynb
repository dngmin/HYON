# %% [markdown]
# # ***Trust curve***
# ---
# 1. J-250
# 1. I-260

# %% [markdown]
# ---
# ### 1. J-250

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

Trust_J250 = {
    "t [s]" : [],
    "T [N]" : []
}
T = 0

for t in np.arange(0,3.06,0.01):

    if 0<=t<0.06:
        T = 3891.176*t
    
    if 0.06<=t<0.18:
        T = 277.275*t + 224.598
    
    elif 0.18<=t<0.29:
        T = -274.227*t + 323.995
    
    elif 0.29<=t<0.42:
        T = -357.938*t + 348.447
    
    elif 0.42<=t<0.54:
        T = -66.945*t + 227.279
    
    elif 0.54<=t<0.66:
        T = -67.807*t + 227.745
    
    elif 0.66<=t<0.78:
        T = -37.563*t + 207.822
    
    elif 0.78<=t<0.90:
        T = -32.811*t + 204.130
    
    elif 0.90<=t<1.02:
        T = -33.571*t + 204.815
    
    elif 1.02<=t<1.14:
        T = -14.215*t + 185.086
    
    elif 1.14<=t<1.26:
        T = -25.686*t + 198.133

    elif 1.26<=t<1.38:
        T = -48.813*t + 227.311
    
    elif 1.38<=t<1.50:
        T = -64.843*t + 249.426
    
    elif 1.50<=t<1.62:
        T = -66.542*t + 251.972
    
    elif 1.62<=t<1.74:
        T = -309.333*t + 645.795
    
    elif 1.74<=t<1.86:
        T = -297.538*t + 625.271
    
    elif 1.86<=t<1.98:
        T = -99.584*t + 257.425
    
    elif 1.98<=t<2.10:
        T = -61.092*t + 181.115
    
    elif 2.10<=t<2.22:
        T = -82.747*t + 226.602

    elif 2.22<=t<2.34:
        T = -63.267*t + 183.382
    
    elif 2.34<=t<2.46:
        T = -61.153*t + 178.429

    elif 2.46<=t<2.58:
        T = -55.830*t + 165.329
    
    elif 2.58<=t<2.70:
        T = -41.776*t + 129.081
    
    elif 2.70<=t<2.82:
        T = -34.841*t + 110.333
    
    elif 2.82<=t<2.94:
        T = -29.518*t + 95.314
    
    elif 2.94<=t<3.06:
        T = -72.343*t +221.204


    
    Trust_J250['t [s]'].append(t)
    Trust_J250['T [N]'].append(T)


df_J250 = pd.DataFrame(Trust_J250)
df_J250.set_index('t [s]')
# Out:
#            T [N]
# t [s]
# 0.00     0.00000
# 0.01    38.91176
# 0.02    77.82352
# 0.03   116.73528
# 0.04   155.64704
# 0.05   194.55880
# 0.06   241.23450
# 0.07   244.00725
# 0.08   246.78000
# 0.09   249.55275
# 0.10   252.32550
# 0.11   255.09825
# 0.12   257.87100
# 0.13   260.64375
# 0.14   263.41650
# 0.15   266.18925
# 0.16   268.96200
# 0.17   271.73475
# 0.18   274.63414
# 0.19   271.89187
# 0.20   269.14960
# 0.21   266.40733
# 0.22   263.66506
# 0.23   260.92279
# 0.24   258.18052
# 0.25   255.43825
# 0.26   252.69598
# 0.27   249.95371
# 0.28   247.21144
# 0.29   244.64498
# 0.30   241.06560
# 0.31   237.48622
# 0.32   233.90684
# 0.33   230.32746
# 0.34   226.74808
# 0.35   223.16870
# 0.36   219.58932
# 0.37   216.00994
# 0.38   212.43056
# 0.39   208.85118
# 0.40   205.27180
# 0.41   201.69242
# 0.42   199.16210
# 0.43   198.49265
# 0.44   197.82320
# 0.45   197.15375
# 0.46   196.48430
# 0.47   195.81485
# 0.48   195.14540
# 0.49   194.47595
# 0.50   193.80650
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(Trust_J250['t [s]'],Trust_J250['T [N]'])
plt.title("Trust curve yosou [J-250]")
plt.xlabel("t [s]")
plt.ylabel("Trust [N]")
# Out:
# Text(0, 0.5, 'Trust [N]')

# %%
df_J250.to_csv("J-250.csv",encoding='utf -8 -sig',index=False)

# %% [markdown]
# ---
# ### 2. I-260

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

Trust_I260 = {
    "t [s]" : [],
    "T [N]" : []
}
T = 0

for t in np.arange(0,2.20,0.01):

    if 0<=t<0.04:
        T = 3862.802*t
    
    if 0.04<=t<0.13:
        T = 275.253*t + 160.419
    
    elif 0.13<=t<0.22:
        T = -272.227*t + 231.413
    
    elif 0.22<=t<0.30:
        T = -355.328*t + 248.878
    
    elif 0.30<=t<0.39:
        T = -66.456*t + 162.334
    
    elif 0.39<=t<0.47:
        T = -67.312*t + 162.667
    
    elif 0.47<=t<0.56:
        T = -37.289*t + 148.436
    
    elif 0.56<=t<0.65:
        T = -32.572*t + 145.800
    
    elif 0.65<=t<0.73:
        T = -33.326*t + 146.288
    
    elif 0.73<=t<0.82:
        T = -14.111*t + 132.198
    
    elif 0.82<=t<0.91:
        T = -25.499*t + 141.516
    
    elif 0.91<=t<0.99:
        T = -48.458*t + 162.356

    elif 0.99<=t<1.08:
        T = -64.370*t + 178.152
    
    elif 1.08<=t<1.17:
        T = -66.057*t + 179.971
    
    elif 1.17<=t<1.25:
        T = -307.078*t + 461.259
    
    elif 1.25<=t<1.34:
        T = -295.369*t + 446.599
    
    elif 1.34<=t<1.43:
        T = -98.858*t + 183.865
    
    elif 1.43<=t<1.51:
        T = -60.647*t + 129.361
    
    elif 1.51<=t<1.60:
        T = -82.144*t + 161.850
    
    elif 1.60<=t<1.69:
        T = -62.806*t + 130.980

    elif 1.69<=t<1.77:
        T = -60.707*t + 127.443
    
    elif 1.77<=t<1.86:
        T = -55.423*t + 118.086

    elif 1.86<=t<1.95:
        T = -41.471*t + 92.196
    
    elif 1.95<=t<2.03:
        T = -34.587*t + 78.805
    
    elif 2.03<=t<2.12:
        T = -29.303*t + 68.078
    
    elif 2.12<=t<2.20:
        T = -71.816*t + 157.994


    
    Trust_I260['t [s]'].append(t)
    Trust_I260['T [N]'].append(T)


df_I260 = pd.DataFrame(Trust_I260)
df_I260.set_index('t [s]')
# Out:
#            T [N]
# t [s]
# 0.00     0.00000
# 0.01    38.62802
# 0.02    77.25604
# 0.03   115.88406
# 0.04   171.42912
# 0.05   174.18165
# 0.06   176.93418
# 0.07   179.68671
# 0.08   182.43924
# 0.09   185.19177
# 0.10   187.94430
# 0.11   190.69683
# 0.12   193.44936
# 0.13   196.02349
# 0.14   193.30122
# 0.15   190.57895
# 0.16   187.85668
# 0.17   185.13441
# 0.18   182.41214
# 0.19   179.68987
# 0.20   176.96760
# 0.21   174.24533
# 0.22   170.70584
# 0.23   167.15256
# 0.24   163.59928
# 0.25   160.04600
# 0.26   156.49272
# 0.27   152.93944
# 0.28   149.38616
# 0.29   145.83288
# 0.30   142.39720
# 0.31   141.73264
# 0.32   141.06808
# 0.33   140.40352
# 0.34   139.73896
# 0.35   139.07440
# 0.36   138.40984
# 0.37   137.74528
# 0.38   137.08072
# 0.39   136.41532
# 0.40   135.74220
# 0.41   135.06908
# 0.42   134.39596
# 0.43   133.72284
# 0.44   133.04972
# 0.45   132.37660
# 0.46   131.70348
# 0.47   130.91017
# 0.48   130.53728
# 0.49   130.16439
# 0.50   129.79150
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(Trust_I260['t [s]'],Trust_I260['T [N]'])
plt.title("Trust curve yosou [I-260]")
plt.xlabel("t [s]")
plt.ylabel("Trust [N]")
# Out:
# Text(0, 0.5, 'Trust [N]')

# %%
df_I260.to_csv("I-260.csv",encoding='utf -8 -sig',index=False)
