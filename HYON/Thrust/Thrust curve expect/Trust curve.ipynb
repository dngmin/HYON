# %% [markdown]
# # ***Thrust curve***
# ---
# 1. J-250
# 1. I-260
# 1. I-260 (from thrustcurve.org)

# %% [markdown]
# ---
# ### 1. J-250

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

Thrust_J250 = {
    "t [s]" : [],
    "T [N]" : []
}

k = 0.01 # 刻み

for t in np.arange(0,3.06+k,k):

    if 0<=t<0.06:
        T = 6261.107*t
    
    elif 0.06<=t<0.18:
        T = 446.150*t + 361.390
    
    elif 0.18<=t<0.29:
        T = -441.246*t + 521.326
    
    elif 0.29<=t<0.42:
        T = -575.941*t + 560.670
    
    elif 0.42<=t<0.54:
        T = -107.717*t + 356.704
    
    elif 0.54<=t<0.66:
        T = -109.104*t + 366.454
    
    elif 0.66<=t<0.78:
        T = -60.440*t + 334.396
    
    elif 0.78<=t<0.90:
        T = -52.795*t + 328.457
    
    elif 0.90<=t<1.02:
        T = -54.017*t + 329.557
    
    elif 1.02<=t<1.14:
        T = -22.872*t + 297.813
    
    elif 1.14<=t<1.26:
        T = -41.330*t + 318.806

    elif 1.26<=t<1.38:
        T = -78.543*t + 365.755
    
    elif 1.38<=t<1.50:
        T = -104.335*t + 401.340
    
    elif 1.50<=t<1.62:
        T = -107.070*t + 405.436
    
    elif 1.62<=t<1.74:
        T = -497.734*t + 1039.120
    
    elif 1.74<=t<1.86:
        T = -478.755*t + 1006.094
    
    elif 1.86<=t<1.98:
        T = -160.235*t + 414.210
    
    elif 1.98<=t<2.10:
        T = -98.301*t + 291.423
    
    elif 2.10<=t<2.22:
        T = -133.144*t + 364.615

    elif 2.22<=t<2.34:
        T = -101.800*t + 295.072
    
    elif 2.34<=t<2.46:
        T = -98.398*t + 287.102

    elif 2.46<=t<2.58:
        T = -89.833*t + 266.023
    
    elif 2.58<=t<2.70:
        T = -67.219*t + 207.698
    
    elif 2.70<=t<2.82:
        T = -56.061*t + 177.531
    
    elif 2.82<=t<2.94:
        T = -47.496*t + 153.365
    
    elif 2.94<=t<3.06:
        T = -116.404*t + 355.928
    
    else:
        T = 0
    
    Thrust_J250['t [s]'].append(t)
    Thrust_J250['T [N]'].append(T)


df_J250 = pd.DataFrame(Thrust_J250)
df_J250.set_index('t [s]')
# Out:
#            T [N]
# t [s]
# 0.00     0.00000
# 0.01    62.61107
# 0.02   125.22214
# 0.03   187.83321
# 0.04   250.44428
# 0.05   313.05535
# 0.06   388.15900
# 0.07   392.62050
# 0.08   397.08200
# 0.09   401.54350
# 0.10   406.00500
# 0.11   410.46650
# 0.12   414.92800
# 0.13   419.38950
# 0.14   423.85100
# 0.15   428.31250
# 0.16   432.77400
# 0.17   437.23550
# 0.18   441.90172
# 0.19   437.48926
# 0.20   433.07680
# 0.21   428.66434
# 0.22   424.25188
# 0.23   419.83942
# 0.24   415.42696
# 0.25   411.01450
# 0.26   406.60204
# 0.27   402.18958
# 0.28   397.77712
# 0.29   393.64711
# 0.30   387.88770
# 0.31   382.12829
# 0.32   376.36888
# 0.33   370.60947
# 0.34   364.85006
# 0.35   359.09065
# 0.36   353.33124
# 0.37   347.57183
# 0.38   341.81242
# 0.39   336.05301
# 0.40   330.29360
# 0.41   324.53419
# 0.42   311.46286
# 0.43   310.38569
# 0.44   309.30852
# 0.45   308.23135
# 0.46   307.15418
# 0.47   306.07701
# 0.48   304.99984
# 0.49   303.92267
# 0.50   302.84550
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(Thrust_J250['t [s]'],Thrust_J250['T [N]'])
plt.title("Thrust curve expected value [J-250]")
plt.xlabel("t [s]")
plt.ylabel("Trust [N]")
plt.show()

# %%
df_J250.to_csv("J-250.csv",encoding='utf -8 -sig',index=False)

# %% [markdown]
# ---
# ### 2. I-260

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

Thrust_I260 = {
    "t [s]" : [],
    "T [N]" : []
}

k = 0.01 # 刻み

for t in np.arange(0,2.20+k,k):

    if 0<=t<0.04:
        T = 11445.952*t
    
    elif 0.04<=t<0.13:
        T = 815.608*t + 475.341
    
    elif 0.13<=t<0.22:
        T = -806.643*t + 685.706
    
    elif 0.22<=t<0.30:
        T = -1052.880*t + 737.456
    
    elif 0.30<=t<0.39:
        T = -196.919*t + 481.015
    
    elif 0.39<=t<0.47:
        T = -199.454*t + 482.001
    
    elif 0.47<=t<0.56:
        T = -110.491*t + 439.835
    
    elif 0.56<=t<0.65:
        T = -96.515*t + 432.023
    
    elif 0.65<=t<0.73:
        T = -98.748*t + 433.471
    
    elif 0.73<=t<0.82:
        T = -41.812*t + 391.717
    
    elif 0.82<=t<0.91:
        T = -75.556*t + 419.330
    
    elif 0.91<=t<0.99:
        T = -143.585*t + 481.082

    elif 0.99<=t<1.08:
        T = -190.736*t + 527.887
    
    elif 1.08<=t<1.17:
        T = -195.735*t + 533.275
    
    elif 1.17<=t<1.25:
        T = -909.909*t + 1366.767
    
    elif 1.25<=t<1.34:
        T = -875.213*t + 1323.327
    
    elif 1.34<=t<1.43:
        T = -292.927*t + 544.815
    
    elif 1.43<=t<1.51:
        T = -179.704*t + 383.312
    
    elif 1.51<=t<1.60:
        T = -243.401*t + 479.583
    
    elif 1.60<=t<1.69:
        T = -186.101*t + 388.111

    elif 1.69<=t<1.77:
        T = -179.882*t + 377.628
    
    elif 1.77<=t<1.86:
        T = -164.225*t + 349.903

    elif 1.86<=t<1.95:
        T = -122.884*t + 273.187
    
    elif 1.95<=t<2.03:
        T = -102.485*t + 233.509
    
    elif 2.03<=t<2.12:
        T = -86.827*t + 201.723
    
    elif 2.12<=t<2.20:
        T = -212.798*t + 468.156
    
    else:
        T = 0
    
    Thrust_I260['t [s]'].append(t)
    Thrust_I260['T [N]'].append(T)


df_I260 = pd.DataFrame(Thrust_I260)
df_I260.set_index('t [s]')
# Out:
#            T [N]
# t [s]
# 0.00     0.00000
# 0.01   114.45952
# 0.02   228.91904
# 0.03   343.37856
# 0.04   507.96532
# 0.05   516.12140
# 0.06   524.27748
# 0.07   532.43356
# 0.08   540.58964
# 0.09   548.74572
# 0.10   556.90180
# 0.11   565.05788
# 0.12   573.21396
# 0.13   580.84241
# 0.14   572.77598
# 0.15   564.70955
# 0.16   556.64312
# 0.17   548.57669
# 0.18   540.51026
# 0.19   532.44383
# 0.20   524.37740
# 0.21   516.31097
# 0.22   505.82240
# 0.23   495.29360
# 0.24   484.76480
# 0.25   474.23600
# 0.26   463.70720
# 0.27   453.17840
# 0.28   442.64960
# 0.29   432.12080
# 0.30   421.93930
# 0.31   419.97011
# 0.32   418.00092
# 0.33   416.03173
# 0.34   414.06254
# 0.35   412.09335
# 0.36   410.12416
# 0.37   408.15497
# 0.38   406.18578
# 0.39   404.21394
# 0.40   402.21940
# 0.41   400.22486
# 0.42   398.23032
# 0.43   396.23578
# 0.44   394.24124
# 0.45   392.24670
# 0.46   390.25216
# 0.47   387.90423
# 0.48   386.79932
# 0.49   385.69441
# 0.50   384.58950
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(Thrust_I260['t [s]'],Thrust_I260['T [N]'])
plt.title("Thrust curve expected value [I-260]")
plt.xlabel("t [s]")
plt.ylabel("Trust [N]")
plt.show()

# %%
df_I260.to_csv("I-260.csv",encoding='utf -8 -sig',index=False)

# %% [markdown]
# ---
# ### 3. I-260 (from thrustcurve.org)

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

Thrust_I260_orgver = {
    "t [s]" : [],
    "T [N]" : []
}

k = 0.01 # 刻み

for t in np.arange(0,2.3+k,k):
    if 0<=t<0.03:
        T = 11300.3333333333*t
    
    elif 0.03<=t<0.041:
        T = 7827.72727272727*t + 104.178181818182
    
    elif 0.041<=t<0.12:
        T = -142.544303797469*t + 430.959316455696

    elif 0.12<=t<0.216:
        T = -205.291666666666*t + 438.489

    elif 0.216<=t<0.354:
        T = -20.3985507246377*t + 398.552086956522

    elif 0.354<=t<0.497:
        T = -157.503496503497*t + 447.087237762238

    elif 0.497<=t<0.749:
        T = -87.0515873015873*t + 412.072638888889

    elif 0.749<=t<1.002:
        T = -158.102766798419*t + 465.289972332016

    elif 1.002<=t<1.36:
        T = -117.960893854748*t + 425.067815642458

    elif 1.36<=t<1.454:
        T = -389.351063829788*t + 794.158446808512

    elif 1.454<=t<1.502:
        T = -997.104166666666*t + 1677.83145833333

    elif 1.502<=t<1.686:
        T = -382.5163043478260*t + 754.720489130435

    elif 1.686<=t<2.003:
        T = -186.5047318611990*t + 424.244977917981
    
    elif 2.003<=t<2.2:
        T = -117.7309644670050*t + 286.491121827411
    
    elif 2.2<=t<2.3:
        T = -274.8300000000010*t + 632.109000000002
    
    else:
        T = 0
    
    Thrust_I260_orgver['t [s]'].append(t)
    Thrust_I260_orgver['T [N]'].append(T)

df_I260_orgver = pd.DataFrame(Thrust_I260_orgver)
df_I260_orgver.set_index('t [s]')
# Out:
#             T [N]
# t [s]
# 0.00     0.000000
# 0.01   113.003333
# 0.02   226.006667
# 0.03   339.010000
# 0.04   417.287273
# 0.05   423.832101
# 0.06   422.406658
# 0.07   420.981215
# 0.08   419.555772
# 0.09   418.130329
# 0.10   416.704886
# 0.11   415.279443
# 0.12   413.854000
# 0.13   411.801083
# 0.14   409.748167
# 0.15   407.695250
# 0.16   405.642333
# 0.17   403.589417
# 0.18   401.536500
# 0.19   399.483583
# 0.20   397.430667
# 0.21   395.377750
# 0.22   394.064406
# 0.23   393.860420
# 0.24   393.656435
# 0.25   393.452449
# 0.26   393.248464
# 0.27   393.044478
# 0.28   392.840493
# 0.29   392.636507
# 0.30   392.432522
# 0.31   392.228536
# 0.32   392.024551
# 0.33   391.820565
# 0.34   391.616580
# 0.35   391.412594
# 0.36   390.385979
# 0.37   388.810944
# 0.38   387.235909
# 0.39   385.660874
# 0.40   384.085839
# 0.41   382.510804
# 0.42   380.935769
# 0.43   379.360734
# 0.44   377.785699
# 0.45   376.210664
# 0.46   374.635629
# 0.47   373.060594
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(Thrust_I260_orgver['t [s]'],Thrust_I260_orgver['T [N]'])
plt.title("Thrust curve [I-260 thrustcurve_org.ver]")
plt.xlabel("t [s]")
plt.ylabel("Trust [N]")
plt.show()

# %%
df_I260_orgver.to_csv("I-260_orgver.csv",encoding='utf -8 -sig',index=False)
