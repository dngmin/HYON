# %% [markdown]
# ## 5. 데이터 확인

# %%
import pandas as pd
df= pd.read_excel('fruit.xlsx',index_col='no')
df
# Out:
#         日本語     English    한글  kcal
# no
# no1     リンゴ       apple    사과  54.0
# no2    オレンジ      orange   오랜지  47.1
# no3  パイナップル   pineapple  파인애플  50.9
# no4     イチゴ  strawberry    딸기  33.9
# no5      ナシ        pear     배  57.1

# %% [markdown]
# ## DataFrame 확인
# 계산 가능한 데이터에 대해 Column 별로 데이터의 갯수, 평균, 표준편차,최소/최대값 등의 정보를 보여줌

# %%
df.describe()
# Out:
#             kcal
# count   5.000000
# mean   48.600000
# std     9.014433
# min    33.900000
# 25%    47.100000
# 50%    50.900000
# 75%    54.000000
# max    57.100000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, no1 to no5
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   日本語      5 non-null      object
#  1   English  5 non-null      object
#  2   한글       5 non-null      object
#  3   kcal     5 non-null      float64
# dtypes: float64(1), object(3)
# memory usage: 200.0+ bytes

# %%
df.head() #처음 5개의 row를 가져옴
# Out:
#         日本語     English    한글  kcal
# no
# no1     リンゴ       apple    사과  54.0
# no2    オレンジ      orange   오랜지  47.1
# no3  パイナップル   pineapple  파인애플  50.9
# no4     イチゴ  strawberry    딸기  33.9
# no5      ナシ        pear     배  57.1

# %%
df.head(3) #처음 3개의 row를 가져옴
# Out:
#         日本語    English    한글  kcal
# no
# no1     リンゴ      apple    사과  54.0
# no2    オレンジ     orange   오랜지  47.1
# no3  パイナップル  pineapple  파인애플  50.9

# %%
df.tail() #마지막 5개의 row 를 가져옴
# Out:
#         日本語     English    한글  kcal
# no
# no1     リンゴ       apple    사과  54.0
# no2    オレンジ      orange   오랜지  47.1
# no3  パイナップル   pineapple  파인애플  50.9
# no4     イチゴ  strawberry    딸기  33.9
# no5      ナシ        pear     배  57.1

# %%
df.tail(2) #마지막 2개의 row를 가져옴
# Out:
#      日本語     English  한글  kcal
# no
# no4  イチゴ  strawberry  딸기  33.9
# no5   ナシ        pear   배  57.1

# %%
df.values
# Out:
# array([['リンゴ', 'apple', '사과', 54.0],
#        ['オレンジ', 'orange', '오랜지', 47.1],
#        ['パイナップル', 'pineapple', '파인애플', 50.9],
#        ['イチゴ', 'strawberry', '딸기', 33.9],
#        ['ナシ', 'pear', '배', 57.1]], dtype=object)

# %%
df.index
# Out:
# Index(['no1', 'no2', 'no3', 'no4', 'no5'], dtype='object', name='no')

# %%
df.columns
# Out:
# Index(['日本語', 'English', '한글', 'kcal'], dtype='object')

# %%
df.shape #row column 개수
# Out:
# (5, 4)

# %%
df
# Out:
#         日本語     English    한글  kcal
# no
# no1     リンゴ       apple    사과  54.0
# no2    オレンジ      orange   오랜지  47.1
# no3  パイナップル   pineapple  파인애플  50.9
# no4     イチゴ  strawberry    딸기  33.9
# no5      ナシ        pear     배  57.1

# %% [markdown]
# ## Series 확인

# %%
df['kcal'].describe()
# Out:
# count     5.000000
# mean     48.600000
# std       9.014433
# min      33.900000
# 25%      47.100000
# 50%      50.900000
# 75%      54.000000
# max      57.100000
# Name: kcal, dtype: float64

# %%
df['kcal'].min()
# Out:
# 33.9

# %%
df['kcal'].max()
# Out:
# 57.1

# %%
df['kcal'].nlargest(3) #큰 순서대로 3개의 데이터
# Out:
# no
# no5    57.1
# no1    54.0
# no3    50.9
# Name: kcal, dtype: float64

# %%
df['kcal'].mean() #평균
# Out:
# 48.6

# %%
df['kcal'].sum()
# Out:
# 243.0

# %%
df['kcal'].count()
# Out:
# 5

# %%
df['日本語'].unique() # 중복제외 체크
# Out:
# array(['リンゴ', 'オレンジ', 'パイナップル', 'イチゴ', 'ナシ'], dtype=object)

# %%
df['日本語'].nunique() # 중복제외 개수
# Out:
# 5
